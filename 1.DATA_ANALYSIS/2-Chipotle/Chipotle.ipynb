# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.
#
# Fijaos que es un tsv. Eso significa "Tab separated value". IMPORTANTE: El separador es "\t"

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep="\t")

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Step Extra:
#
# Si os fijais, la columna item_price es un string. Hay que quitar el signo del dolar y convertir a float para poder trabajar.
#
# Hay maneras cool de hacer esto, pero os recomiendo lo siguiente:
# - haced un bucle for del df (iterrows)
# - guardaros en una lista (append) el valor sin el dolar y convetido a float
# - actualizad el valor de esa columna con la nueva lista

# %%
new_item_price = []
for index,row in chipo.iterrows():
    new_price = row.loc["item_price"].replace("$", "")
    new_item_price.append(float(new_price))
new_item_price
# Out:
# [2.39,
#  3.39,
#  3.39,
#  2.39,
#  16.98,
#  10.98,
#  1.69,
#  11.75,
#  9.25,
#  9.25,
#  4.45,
#  8.75,
#  8.75,
#  11.25,
#  4.45,
#  2.39,
#  8.49,
#  8.49,
#  2.18,
#  8.75,
#  4.45,
#  8.99,
#  3.39,
#  10.98,
#  3.39,
#  2.39,
#  8.49,
#  8.99,
#  1.09,
#  8.49,
#  2.39,
#  8.99,
#  1.69,
#  8.99,
#  1.09,
#  8.75,
#  8.75,
#  4.45,
#  2.95,
#  11.75,
#  2.15,
#  4.45,
#  11.25,
#  11.75,
#  8.75,
#  10.98,
#  8.99,
#  3.39,
#  8.99,
#  3.99,
#  8.99,
#  2.18,
#  10.98,
#  1.09,
#  8.99,
#  2.39,
#  9.25,
#  11.25,
#  11.75,
#  2.15,
#  4.45,
#  9.25,
#  11.25,
#  8.75,
#  8.99,
#  8.99,
#  3.39,
#  8.99,
#  10.98,
#  8.99,
#  1.69,
#  8.99,
#  3.99,
#  8.75,
#  4.45,
#  8.75,
#  8.75,
#  2.15,
#  8.75,
#  11.25,
#  2.15,
#  9.25,
#  8.75,
#  8.75,
#  9.25,
#  8.49,
#  8.99,
#  1.09,
#  9.25,
#  2.95,
#  11.75,
#  11.75,
#  9.25,
#  11.75,
#  4.45,
#  9.25,
#  4.45,
#  11.75,
#  8.75,
#  8.75,
#  4.45,
#  8.99,
#  8.99,
#  3.99,
#  8.49,
#  3.39,
#  8.99,
#  1.09,
#  9.25,
#  4.45,
#  8.75,
#  2.95,
#  4.45,
#  2.39,
#  8.49,
#  8.99,
#  8.49,
#  1.09,
#  8.99,
#  3.99,
#  8.75,
#  9.25,
#  4.45,
#  11.25,
#  4.45,
#  8.99,
#  1.09,
#  9.25,
#  2.95,
#  4.45,
#  11.75,
#  4.45,
#  8.49,
#  2.39,
#  10.98,
#  22.5,
#  11.75,
#  4.45,
#  11.25,
#  4.45,
#  11.25,
#  4.45,
#  11.25,
#  11.25,
#  11.75,
#  9.25,
#  4.45,
#  11.48,
#  17.98,
#  1.69,
#  17.5,
#  4.45,
#  8.49,
#  2.39,
#  17.5,
#  4.45,
#  4.45,
#  11.25,
#  11.75,
#  10.98,
#  8.49,
#  10.98,
#  2.18,
#  11.48,
#  8.49,
#  2.39,
#  4.45,
#  11.25,
#  11.75,
#  8.75,
#  8.49,
#  2.18,
#  8.49,
#  3.39,
#  8.49,
#  8.99,
#  10.98,
#  11.48,
#  8.49,
#  1.09,
#  1.09,
#  9.25,
#  8.75,
#  2.95,
#  9.25,
#  4.45,
#  11.25,
#  11.48,
#  8.49,
#  8.49,
#  8.99,
#  2.39,
#  11.25,
#  8.75,
#  2.95,
#  1.09,
#  8.99,
#  8.49,
#  2.39,
#  10.98,
#  1.09,
#  3.99,
#  11.25,
#  8.75,
#  8.49,
#  3.39,
#  8.75,
#  9.25,
#  2.15,
#  11.25,
#  11.25,
#  11.25,
#  4.45,
#  22.5,
#  4.45,
#  11.75,
#  8.75,
#  17.5,
#  8.75,
#  9.25,
#  8.75,
#  2.15,
#  9.25,
#  4.3,
#  8.75,
#  11.25,
#  2.15,
#  8.99,
#  1.09,
#  8.99,
#  3.99,
#  8.75,
#  2.95,
#  2.95,
#  11.75,
#  5.9,
#  9.25,
#  9.25,
#  11.75,
#  9.25,
#  2.95,
#  17.5,
#  8.75,
#  9.25,
#  10.98,
#  8.99,
#  1.09,
#  1.09,
#  1.09,
#  8.99,
#  10.98,
#  1.09,
#  8.75,
#  8.75,
#  9.25,
#  9.25,
#  8.75,
#  8.75,
#  8.99,
#  8.99,
#  8.99,
#  1.09,
#  11.75,
#  1.25,
#  8.99,
#  2.39,
#  9.25,
#  2.95,
#  8.99,
#  3.99,
#  8.49,
#  2.39,
#  8.49,
#  8.49,
#  8.49,
#  1.69,
#  8.49,
#  3.99,
#  8.99,
#  1.69,
#  1.09,
#  23.78,
#  17.5,
#  2.15,
#  8.75,
#  9.25,
#  9.25,
#  8.75,
#  4.45,
#  8.75,
#  11.25,
#  11.25,
#  1.25,
#  9.25,
#  4.45,
#  11.25,
#  11.75,
#  11.75,
#  6.49,
#  8.99,
#  2.39,
#  8.49,
#  2.39,
#  11.25,
#  8.75,
#  2.15,
#  8.99,
#  1.69,
#  8.75,
#  11.25,
#  2.15,
#  4.45,
#  8.75,
#  8.49,
#  8.99,
#  17.5,
#  8.49,
#  1.09,
#  1.09,
#  8.75,
#  1.25,
#  2.15,
#  11.08,
#  8.49,
#  8.49,
#  8.99,
#  2.39,
#  8.75,
#  2.15,
#  1.5,
#  11.25,
#  2.15,
#  8.49,
#  8.49,
#  11.75,
#  9.25,
#  11.75,
#  1.25,
#  11.25,
#  8.75,
#  4.45,
#  6.49,
#  9.25,
#  2.95,
#  11.25,
#  4.45,
#  1.25,
#  1.25,
#  8.49,
#  2.39,
#  2.18,
#  8.49,
#  2.18,
#  22.16,
#  17.5,
#  8.75,
#  2.95,
#  6.49,
#  8.99,
#  3.39,
#  3.39,
#  8.99,
#  8.49,
#  11.25,
#  2.15,
#  11.25,
#  2.95,
#  11.25,
#  1.25,
#  8.99,
#  1.09,
#  8.75,
#  8.75,
#  9.25,
#  2.95,
#  11.75,
#  1.5,
#  8.99,
#  1.09,
#  11.25,
#  1.25,
#  1.25,
#  11.25,
#  11.75,
#  2.15,
#  8.99,
#  1.69,
#  11.75,
#  6.49,
#  8.75,
#  9.25,
#  11.25,
#  4.45,
#  1.25,
#  11.25,
#  4.45,
#  8.49,
#  8.99,
#  8.49,
#  8.99,
#  11.25,
#  1.25,
#  11.75,
#  1.25,
#  11.75,
#  9.25,
#  4.45,
#  11.25,
#  2.15,
#  32.94,
#  1.25,
#  11.25,
#  11.48,
#  1.69,
#  1.09,
#  17.5,
#  4.45,
#  6.49,
#  9.25,
#  8.75,
#  9.25,
#  9.25,
#  8.75,
#  8.75,
#  2.15,
#  2.95,
#  17.5,
#  10.98,
#  11.48,
#  11.48,
#  3.39,
#  8.99,
#  1.69,
#  8.99,
#  1.09,
#  10.98,
#  3.39,
#  8.99,
#  1.09,
#  9.25,
#  8.75,
#  11.25,
#  4.45,
#  2.95,
#  9.25,
#  22.2,
#  8.49,
#  8.99,
#  8.75,
#  8.75,
#  11.75,
#  8.75,
#  11.25,
#  9.25,
#  11.25,
#  11.25,
#  8.75,
#  11.25,
#  2.95,
#  1.25,
#  8.49,
#  1.69,
#  11.75,
#  11.25,
#  8.75,
#  8.75,
#  4.45,
#  8.49,
#  3.99,
#  8.49,
#  3.99,
#  11.48,
#  1.69,
#  1.09,
#  11.25,
#  1.5,
#  10.58,
#  1.69,
#  9.25,
#  11.25,
#  8.75,
#  9.25,
#  11.25,
#  11.25,
#  8.75,
#  11.75,
#  8.75,
#  8.75,
#  8.75,
#  2.15,
#  11.25,
#  11.75,
#  2.5,
#  4.45,
#  9.25,
#  4.45,
#  11.25,
#  8.49,
#  3.99,
#  9.25,
#  9.25,
#  11.25,
#  9.25,
#  11.75,
#  11.25,
#  1.25,
#  23.5,
#  1.25,
#  8.99,
#  8.49,
#  7.4,
#  7.4,
#  8.75,
#  1.25,
#  4.45,
#  8.75,
#  2.15,
#  8.75,
#  4.45,
#  7.4,
#  7.4,
#  7.4,
#  8.99,
#  3.99,
#  8.99,
#  1.69,
#  8.75,
#  8.75,
#  8.75,
#  8.75,
#  11.25,
#  11.25,
#  2.95,
#  8.75,
#  18.5,
#  8.49,
#  3.99,
#  2.95,
#  9.25,
#  9.25,
#  3.0,
#  1.25,
#  8.75,
#  9.25,
#  4.45,
#  8.75,
#  11.25,
#  4.45,
#  10.98,
#  22.16,
#  4.45,
#  8.75,
#  9.25,
#  6.49,
#  9.25,
#  11.25,
#  8.75,
#  9.25,
#  2.15,
#  9.25,
#  4.45,
#  9.25,
#  2.95,
#  9.25,
#  8.75,
#  9.25,
#  1.25,
#  1.25,
#  8.75,
#  8.75,
#  9.25,
#  4.45,
#  11.75,
#  11.75,
#  11.75,
#  9.25,
#  9.25,
#  16.98,
#  2.39,
#  3.39,
#  3.39,
#  9.25,
#  11.75,
#  11.25,
#  2.15,
#  8.75,
#  9.25,
#  4.45,
#  10.98,
#  11.25,
#  9.25,
#  22.5,
#  9.25,
#  2.95,
#  1.5,
#  11.48,
#  8.49,
#  1.69,
#  8.49,
#  8.49,
#  8.49,
#  6.78,
#  11.75,
#  4.45,
#  8.75,
#  4.45,
#  11.89,
#  9.39,
#  8.75,
#  2.95,
#  1.25,
#  9.25,
#  8.75,
#  23.78,
#  8.75,
#  9.25,
#  2.15,
#  2.15,
#  1.25,
#  8.49,
#  3.99,
#  10.98,
#  1.09,
#  8.75,
#  4.45,
#  8.75,
#  11.75,
#  2.95,
#  4.45,
#  9.25,
#  8.75,
#  8.49,
#  3.99,
#  22.5,
#  11.25,
#  1.25,
#  8.75,
#  8.75,
#  18.5,
#  6.49,
#  8.75,
#  8.75,
#  4.45,
#  8.49,
#  3.99,
#  8.99,
#  1.09,
#  8.49,
#  2.39,
#  11.48,
#  1.69,
#  2.5,
#  9.25,
#  1.5,
#  17.5,
#  2.95,
#  8.75,
#  4.45,
#  11.75,
#  8.75,
#  8.49,
#  1.69,
#  8.49,
#  3.99,
#  8.99,
#  8.99,
#  3.99,
#  8.99,
#  11.25,
#  4.45,
#  1.25,
#  3.99,
#  10.98,
#  7.4,
#  3.0,
#  7.4,
#  4.0,
#  8.49,
#  3.99,
#  9.25,
#  4.45,
#  11.25,
#  1.25,
#  11.75,
#  1.25,
#  11.25,
#  2.15,
#  11.25,
#  4.45,
#  3.75,
#  11.75,
#  8.99,
#  2.39,
#  8.75,
#  4.45,
#  1.25,
#  8.99,
#  8.49,
#  2.18,
#  8.49,
#  2.18,
#  1.09,
#  8.75,
#  2.95,
#  1.25,
#  1.5,
#  11.25,
#  9.25,
#  2.95,
#  1.25,
#  8.49,
#  3.99,
#  11.48,
#  3.99,
#  8.49,
#  11.25,
#  1.25,
#  8.99,
#  1.69,
#  11.25,
#  1.25,
#  6.49,
#  8.75,
#  9.25,
#  8.75,
#  2.95,
#  8.75,
#  11.75,
#  8.69,
#  8.69,
#  2.29,
#  3.99,
#  8.49,
#  8.75,
#  8.75,
#  1.25,
#  11.75,
#  11.25,
#  11.25,
#  11.25,
#  1.25,
#  9.25,
#  11.75,
#  6.49,
#  3.99,
#  8.49,
#  11.25,
#  2.15,
#  11.25,
#  11.89,
#  8.99,
#  1.69,
#  8.99,
#  8.99,
#  3.99,
#  8.99,
#  9.25,
#  9.25,
#  2.15,
#  7.4,
#  7.4,
#  8.75,
#  8.75,
#  9.25,
#  4.45,
#  11.25,
#  1.25,
#  11.75,
#  11.25,
#  1.25,
#  3.99,
#  8.49,
#  8.49,
#  8.49,
#  8.99,
#  8.75,
#  2.15,
#  1.25,
#  8.49,
#  1.09,
#  1.09,
#  8.75,
#  2.95,
#  1.25,
#  9.25,
#  1.25,
#  2.15,
#  11.25,
#  1.25,
#  4.45,
#  8.75,
#  2.5,
#  8.9,
#  8.75,
#  8.75,
#  8.75,
#  11.25,
#  11.25,
#  10.98,
#  3.99,
#  10.98,
#  3.99,
#  1.69,
#  8.99,
#  9.25,
#  8.75,
#  8.99,
#  1.09,
#  9.25,
#  2.95,
#  8.75,
#  9.25,
#  3.99,
#  8.49,
#  8.75,
#  8.75,
#  22.5,
#  10.98,
#  3.27,
#  3.99,
#  8.99,
#  1.09,
#  11.08,
#  8.75,
#  4.45,
#  11.08,
#  3.99,
#  8.49,
#  4.3,
#  9.25,
#  8.75,
#  11.25,
#  11.25,
#  9.25,
#  8.49,
#  8.99,
#  8.49,
#  8.75,
#  2.95,
#  4.45,
#  9.25,
#  2.95,
#  9.25,
#  8.75,
#  11.25,
#  4.45,
#  16.98,
#  8.49,
#  2.39,
#  11.25,
#  3.75,
#  9.25,
#  4.45,
#  9.25,
#  9.25,
#  4.45,
#  8.75,
#  9.25,
#  8.75,
#  9.25,
#  9.25,
#  9.25,
#  11.48,
#  8.99,
#  22.5,
#  11.75,
#  11.25,
#  1.25,
#  8.75,
#  2.15,
#  1.25,
#  11.25,
#  8.75,
#  1.25,
#  11.25,
#  1.5,
#  11.25,
#  11.25,
#  9.25,
#  6.49,
#  8.9,
#  8.75,
#  4.45,
#  11.25,
#  1.25,
#  17.5,
#  9.25,
#  8.75,
#  11.75,
#  3.0,
#  8.49,
#  8.49,
#  10.98,
#  8.99,
#  3.99,
#  8.75,
#  4.45,
#  8.99,
#  1.69,
#  11.75,
#  8.75,
#  11.25,
#  4.45,
#  11.75,
#  1.25,
#  11.75,
#  2.95,
#  8.99,
#  8.99,
#  2.18,
#  17.98,
#  8.99,
#  8.49,
#  1.69,
#  11.75,
#  11.25,
#  2.95,
#  3.75,
#  9.25,
#  11.75,
#  8.75,
#  2.15,
#  1.5,
#  8.49,
#  8.49,
#  3.39,
#  8.69,
#  3.89,
#  8.75,
#  4.45,
#  8.75,
#  11.25,
#  2.15,
#  8.75,
#  8.49,
#  1.69,
#  8.49,
#  8.49,
#  1.25,
#  8.75,
#  11.75,
#  11.75,
#  8.99,
#  1.09,
#  8.75,
#  4.45,
#  8.75,
#  2.95,
#  8.75,
#  2.15,
#  3.99,
#  8.49,
#  8.99,
#  3.99,
#  8.49,
#  1.69,
#  1.09,
#  8.99,
#  1.09,
#  9.25,
#  8.75,
#  8.99,
#  2.39,
#  1.25,
#  1.25,
#  11.25,
#  11.25,
#  9.25,
#  9.25,
#  11.25,
#  1.5,
#  3.99,
#  8.49,
#  11.25,
#  9.25,
#  11.25,
#  17.5,
#  8.75,
#  8.9,
#  8.75,
#  8.75,
#  8.99,
#  2.39,
#  11.25,
#  9.25,
#  2.15,
#  11.25,
#  1.25,
#  11.75,
#  1.25,
#  11.25,
#  11.75,
#  1.25,
#  11.25,
#  11.25,
#  8.49,
#  10.98,
#  8.75,
#  1.25,
#  8.75,
#  ...]

# %%
chipo.loc[:,"item_price"] = new_item_price
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN       2.39
# 1                                          [Clementine]       3.39
# 2                                               [Apple]       3.39
# 3                                                   NaN       2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...      11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...      11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...      11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...       8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
maximo = chipo.loc[:,"item_price"].max()
chipo.loc[chipo.loc[:,"item_price"] == maximo]["item_name"].iloc[0]
# Out:
# 'Chips and Fresh Tomato Salsa'

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
productos_10 = chipo.loc[chipo["item_price"]>10.00]
len(productos_10)
# Out:
# 1130

# %%
productos_10
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...      10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...      11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...      11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...      10.98
# ...                                                 ...        ...
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...      11.75
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...      11.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...      11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...      11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...      11.25
#
# [1130 rows x 5 columns]

# %% [markdown]
# Extra: Cuántos pedidos se han hecho con un producto de más de 10$

# %%
productos_10.loc[:,"quantity"].sum()
# Out:
# np.int64(1314)

# %% [markdown]
# ### Step 5. a - How much money we earned selling our most expensive product?
#
# Busca el producto mas caro (si hay mas de uno da igual, coge el uno de ellos). Guardate su nombre y precio.
# Filtra las filas por ese producto con el nombre.
# Multiplica las cantidades del resultado filtrado por el precio que guardaste.

# %%
nombre = chipo.loc[chipo.loc[:,"item_price"] == maximo]["item_name"].iloc[0]
precio = chipo.loc[chipo.loc[:,"item_price"] == maximo]["item_price"].iloc[0]

filtrado = chipo.loc[chipo["item_name"] == nombre]
filtrado.loc[:,"quantity"].sum()*precio
# Out:
# np.float64(5752.5)

# %% [markdown]
# ### Step 5. b - How much money we earned selling our cheapest product?
#
# Lo mismo que antes pero con el mas barato.

# %%
minimo = chipo.loc[:,"item_price"].min()

nombre2 = chipo.loc[chipo.loc[:,"item_price"] == minimo]["item_name"].iloc[0]
precio = chipo.loc[chipo.loc[:,"item_price"] == minimo]["item_price"].iloc[0]

filtrado = chipo.loc[chipo["item_name"] == nombre2]
filtrado.loc[:,"quantity"].sum()*precio
# Out:
# np.float64(137.34)

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.loc[:,"item_name"].sort_values()
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
#               ...
# 2384    Veggie Soft Tacos
# 781     Veggie Soft Tacos
# 2851    Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# 1395    Veggie Soft Tacos
# Name: item_name, Length: 4622, dtype: object

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.loc[chipo.loc[:,"item_name"] == nombre]["quantity"].iloc[0]
# Out:
# np.int64(1)

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
salad = chipo.loc[chipo.loc[:,"item_name"] == "Veggie Salad Bowl"]
salad["quantity"].sum()
# Out:
# np.int64(18)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
canned = chipo.loc[chipo.loc[:,"item_name"] == "Canned Soda"]
len(canned[canned["quantity"]>2])
# Out:
# 1
